# %%
import pandas as pd

# %%
df_station=pd.read_csv('./station.csv')

df_station.head(2)
# Out:
#   station_id                name        lat        long install_date  \
# 0      BT-01  3rd Ave & Broad St  47.618418 -122.350964   10/13/2014
# 1      BT-03   2nd Ave & Vine St  47.615829 -122.348564   10/13/2014
#
#    install_dockcount modification_date  current_dockcount decommission_date
# 0                 18               NaN                 18               NaN
# 1                 16               NaN                 16               NaN

# %%
df_weather=pd.read_csv('./weather.csv')
df_weather.head(2)
# Out:
#          Date  Max_Temperature_F  Mean_Temperature_F  Min_TemperatureF  \
# 0  10/13/2014                 71                62.0                54
# 1  10/14/2014                 63                59.0                55
#
#    Max_Dew_Point_F  MeanDew_Point_F  Min_Dewpoint_F  Max_Humidity  \
# 0               55               51              46            87
# 1               52               51              50            88
#
#    Mean_Humidity  Min_Humidity  ...  Mean_Sea_Level_Pressure_In  \
# 0             68            46  ...                       29.79
# 1             78            63  ...                       29.75
#
#    Min_Sea_Level_Pressure_In  Max_Visibility_Miles  Mean_Visibility_Miles  \
# 0                      29.65                    10                     10
# 1                      29.54                    10                      9
#
#    Min_Visibility_Miles  Max_Wind_Speed_MPH  Mean_Wind_Speed_MPH  \
# ...

# %%
df_trip=pd.read_csv('./trip.csv' , error_bad_lines=False)
df_trip.head(2)
# Out:
# /home/shosh/ltuc/401/Data-Analysis-with-Pandas/.venv/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3441: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# b'Skipping line 50794: expected 12 fields, saw 20\n'
#    trip_id         starttime          stoptime    bikeid  tripduration  \
# 0      431  10/13/2014 10:31  10/13/2014 10:48  SEA00298       985.935
# 1      432  10/13/2014 10:32  10/13/2014 10:48  SEA00195       926.375
#
#      from_station_name                                    to_station_name  \
# 0  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 1  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
#
#   from_station_id to_station_id usertype gender  birthyear
# 0          CBD-06         PS-04   Member   Male     1960.0
# 1          CBD-06         PS-04   Member   Male     1970.0

# %% [markdown]
# # What is the average trip duration for a borrowed bicycle?

# %%
avg_trip_duration = df_trip['tripduration'].mean()
avg_trip_duration
# Out:
# 1178.2956753399776

# %% [markdown]
# # What’s the most common age of a bicycle-sharer?

# %%
most_common_age = 2021 - df_trip['birthyear'].mode().iloc[0]
most_common_age
# Out:
# 34.0

# %% [markdown]
# # Given all the weather data here, find the average precipitation per month, and the median precipitation.

# %%
avg_per_month_mean= df_weather['Precipitation_In'].mean() * 30
weather_median= df_weather['Precipitation_In'].median() 
[avg_per_month_mean , weather_median]
# Out:
# [3.1519593613933234, 0.0]

# %% [markdown]
# # What’s the average number of bikes at a given bike station?

# %%
avg_num_of_bike = df_station['install_dockcount'].mean()
avg_num_of_bike
# Out:
# 17.586206896551722

# %% [markdown]
# # When a bike station is modified, is it more likely that it’ll lose bikes or gain bikes? How do you know?

# %% [markdown]
# # Come up with 3 more questions that can be answered with this data set.
# # 1 ) show all data  of male

# %%
count_of_male = df_trip[df_trip['gender'] == 'Male']
count_of_male
# Out:
#         trip_id         starttime          stoptime    bikeid  tripduration  \
# 0           431  10/13/2014 10:31  10/13/2014 10:48  SEA00298       985.935
# 1           432  10/13/2014 10:32  10/13/2014 10:48  SEA00195       926.375
# 4           435  10/13/2014 10:34  10/13/2014 10:49  SEA00202       923.923
# 5           436  10/13/2014 10:34  10/13/2014 10:47  SEA00337       808.805
# 6           437  10/13/2014 11:35  10/13/2014 11:45  SEA00202       596.715
# ...         ...               ...               ...       ...           ...
# 286841   255230   8/31/2016 21:27   8/31/2016 21:30  SEA00056       198.324
# 286843   255232   8/31/2016 21:59   8/31/2016 22:04  SEA00499       308.484
# 286845   255234   8/31/2016 22:02   8/31/2016 22:17  SEA00448       879.160
# 286847   255236   8/31/2016 22:13   8/31/2016 22:25  SEA00254       674.993
# 286848   255237   8/31/2016 22:37   8/31/2016 22:39  SEA00330       144.477
#
# ...

# %% [markdown]
# # 2 ) show all  rain event

# %%
all_rain_event = df_weather[df_weather['Events'] == 'Rain']
all_rain_event
# Out:
#            Date  Max_Temperature_F  Mean_Temperature_F  Min_TemperatureF  \
# 0    10/13/2014                 71                62.0                54
# 1    10/14/2014                 63                59.0                55
# 2    10/15/2014                 62                58.0                54
# 3    10/16/2014                 71                61.0                52
# 4    10/17/2014                 64                60.0                57
# ..          ...                ...                 ...               ...
# 634    7/8/2016                 73                66.0                60
# 635    7/9/2016                 71                64.0                57
# 648   7/22/2016                 71                66.0                61
# 664    8/7/2016                 72                66.0                60
# 688   8/31/2016                 71                65.0                59
#
#      Max_Dew_Point_F  MeanDew_Point_F  Min_Dewpoint_F  Max_Humidity  \
# ...

# %% [markdown]
# # 3 ) show all  tripduration less than 500

# %%
tripduration_less_500 = df_trip[df_trip['tripduration'] <=500]
tripduration_less_500
# Out:
#         trip_id         starttime          stoptime    bikeid  tripduration  \
# 18          450  10/13/2014 11:40  10/13/2014 11:49  SEA00107       499.734
# 22          455  10/13/2014 11:42  10/13/2014 11:49  SEA00373       437.689
# 23          456  10/13/2014 11:43  10/13/2014 11:51  SEA00121       483.154
# 24          457  10/13/2014 11:43  10/13/2014 11:51  SEA00029       479.382
# 26          459  10/13/2014 11:43  10/13/2014 11:51  SEA00118       481.629
# ...         ...               ...               ...       ...           ...
# 286838   255227   8/31/2016 20:58   8/31/2016 21:02  SEA00107       273.808
# 286839   255228   8/31/2016 21:11   8/31/2016 21:15  SEA00499       235.553
# 286841   255230   8/31/2016 21:27   8/31/2016 21:30  SEA00056       198.324
# 286843   255232   8/31/2016 21:59   8/31/2016 22:04  SEA00499       308.484
# 286848   255237   8/31/2016 22:37   8/31/2016 22:39  SEA00330       144.477
#
# ...

# %%
def test():

    def assert_equal(actual,expected):
        assert actual == expected, f"Expected {expected} but got {actual}"

    assert_equal(avg_trip_duration, 1178.2956753399776)
    assert_equal(avg_per_month_mean, 3.1519593613933234)
    assert_equal(weather_median, 0.0)
    assert_equal(most_common_age, 34)
  

    print("Success!!!")

test()
# Out:
# Success!!!
